# %%
# Importar paquetes
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
# Funcion que calcula la pdf para la distribución normal
def normal_pdf(x, mu=0, sigma=1):
    return (1 / (sigma * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mu) / sigma)**2)

# %% [markdown]
# Si queremos calcular $ e^2 $ lo podemos hacer con la funcion de numpy `np.exp(2)`

# %%
# La funcion de scipy scipy.stats.norm.pdf() es equivalente
# ejemplo
print(normal_pdf(2, mu=0, sigma=1))
print(norm.pdf(2, loc=0, scale=1))
# Out:
# 0.05399096651318806
# 0.05399096651318806

# %%
x_axis = np.linspace(-8, 8, 1000)
y_values = []
for i in x_axis:
    y_values.append(normal_pdf(i, mu=0, sigma=1))

# %%
np.sum(norm.pdf(x_axis, loc=0, scale=1))
# Out:
# 62.437499999999936

# %%
plt.figure()
plt.plot(x_axis, y_values)

# %%
cumulative_y_values = []
for index in range(len(y_values)):
    cumulative = np.sum(y_values[:index])
    cumulative_y_values.append(cumulative)
# Normalizar
cumulative_y_values = cumulative_y_values / np.sum(cumulative)

# %%
plt.figure()
plt.plot(x_axis, cumulative_y_values)

# %%
y_values_scipy = norm.cdf(x_axis, loc=0, scale=1)
plt.figure()
plt.plot(x_axis, y_values_scipy)

# %%
x_axis
# Out:
# array([-8.        , -7.98398398, -7.96796797, -7.95195195, -7.93593594,
#        -7.91991992, -7.9039039 , -7.88788789, -7.87187187, -7.85585586,
#        -7.83983984, -7.82382382, -7.80780781, -7.79179179, -7.77577578,
#        -7.75975976, -7.74374374, -7.72772773, -7.71171171, -7.6956957 ,
#        -7.67967968, -7.66366366, -7.64764765, -7.63163163, -7.61561562,
#        -7.5995996 , -7.58358358, -7.56756757, -7.55155155, -7.53553554,
#        -7.51951952, -7.5035035 , -7.48748749, -7.47147147, -7.45545546,
#        -7.43943944, -7.42342342, -7.40740741, -7.39139139, -7.37537538,
#        -7.35935936, -7.34334334, -7.32732733, -7.31131131, -7.2952953 ,
#        -7.27927928, -7.26326326, -7.24724725, -7.23123123, -7.21521522,
#        -7.1991992 , -7.18318318, -7.16716717, -7.15115115, -7.13513514,
#        -7.11911912, -7.1031031 , -7.08708709, -7.07107107, -7.05505506,
#        -7.03903904, -7.02302302, -7.00700701, -6.99099099, -6.97497497,
# ...

# %%
np.var([1,0,1])
# Out:
# 0.22222222222222224
